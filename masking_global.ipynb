# %% [markdown]
# #  Lottery Notebook
#
# ### imports :

# %%
import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image
import numpy as np
import torch.nn.utils.prune as prune
import matplotlib.pyplot as plt
from pruning import Pruning_tool
import copy
import time
if torch.cuda.is_available():
    device = torch.device("cuda:0")
else:
    device = torch.device("cpu")
print('using', device)
# Out:
# using cuda:0

# %% [markdown]
# ## Model :

# %%
class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()

        self.fc1 = nn.Linear(784, 400)
        self.fc2 = nn.Linear(400, 200)
        self.fc3 = nn.Linear(200,100)
        self.fc41 = nn.Linear(100, 32)
        self.fc42 = nn.Linear(100, 32)
        self.fc5 = nn.Linear(32, 100)
        self.fc6 = nn.Linear(100,200)
        self.fc7 = nn.Linear(200,400)
        self.fc8 = nn.Linear(400, 784)

    def encode(self, x):
        h1 = F.relu(self.fc3(self.fc2(self.fc1(x))))
        return self.fc41(h1), self.fc42(h1)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mu + eps*std

    def decode(self, z):
        h3 = F.relu(self.fc7(self.fc6(self.fc5(z))))
        return torch.sigmoid(self.fc8(h3))

    def forward(self, x):
        mu, logvar = self.encode(x.view(-1, 784))
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar



# Reconstruction + KL divergence losses summed over all elements and batch
def loss_function(recon_x, x, mu, logvar, beta):
    """ Compute the loss function between recon_x (output of the VAE) 
    and x (input of the VAE)
    """
    BCE = F.binary_cross_entropy(recon_x, x.view(-1, 784), reduction='sum')
    KLD = 0.5 * torch.sum(logvar.exp() + mu.pow(2) - 1 - logvar)
    return BCE + beta*KLD

epochs = 10
batch_size = 64
log_interval = 100

mnist_trainset = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.ToTensor()),
                   batch_size=batch_size, shuffle=True)

mnist_testset = test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.ToTensor()),
                  batch_size=batch_size, shuffle=True)

model = VAE().to(device)
print(model.parameters)
optimizer = optim.Adam(model.parameters(), lr=7e-4)
rewind_state_dict = copy.deepcopy(model.state_dict()) 
step = 0
# Out:
# <bound method Module.parameters of VAE(
#   (fc1): Linear(in_features=784, out_features=400, bias=True)
#   (fc2): Linear(in_features=400, out_features=200, bias=True)
#   (fc3): Linear(in_features=200, out_features=100, bias=True)
#   (fc41): Linear(in_features=100, out_features=32, bias=True)
#   (fc42): Linear(in_features=100, out_features=32, bias=True)
#   (fc5): Linear(in_features=32, out_features=100, bias=True)
#   (fc6): Linear(in_features=100, out_features=200, bias=True)
#   (fc7): Linear(in_features=200, out_features=400, bias=True)
#   (fc8): Linear(in_features=400, out_features=784, bias=True)
# )>

# %% [markdown]
# ## Training with global Iterative Magnitude Pruning

# %%
from pruning import Pruning

plt_loss = []
prstat = Pruning_tool()
first_training = True
pruning_amount = np.linspace(0, 0.99, 10)
final_pa = pruning_amount[-1]

for pa in pruning_amount:
    print(round(pa*100,3),'% of weights pruned')
    # global pruning
    cutting_value = prstat.compute_global_criterion(model, pa)
    for name, module in model.named_modules():
        if isinstance(module, torch.nn.Linear):
            pr = Pruning(module)
            pr.set_mask_globally(cutting_value)
            module.register_forward_pre_hook(pr)

    for name, param in model.named_parameters(): 
        param.data = rewind_state_dict[name].clone()
        
    epochs = 20 if pa == final_pa else 10
    for epoch in range(epochs):

        model.train()
        train_loss = 0
        for batch_idx, (data, _) in enumerate(mnist_trainset):
            data = data.to(device)
            optimizer.zero_grad()
            recon_batch, mu, logvar = model(data)
            beta = 1
            loss = loss_function(recon_batch, data, mu, logvar, beta)
            loss.backward()
            train_loss += loss.item()
            optimizer.step()
            step += 1
            
            if  first_training and batch_idx == 500 :
                rewind_state_dict = copy.deepcopy(model.state_dict())
                first_training = False
                print('rewind state saved')
            
            #if batch_idx % log_interval == 0:
            #    print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            #        epoch, batch_idx * len(data), len(mnist_trainset.dataset),
            #        100. * batch_idx / len(mnist_trainset),
            #        loss.item() / len(data)))
            #    plt_loss.append(loss.item() / len(data))  # For ploting loss
        print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / len(mnist_trainset.dataset)))
    _, _, _ = model(data)
    prstat.stats_pruning(model)
# Out:
# 0.0 % of weights pruned
# rewind state saved
# ====> Epoch: 0 Average loss: 163.6184
# ====> Epoch: 1 Average loss: 126.1361
# ====> Epoch: 2 Average loss: 118.5564
# ====> Epoch: 3 Average loss: 114.9881
# ====> Epoch: 4 Average loss: 112.5811
# ====> Epoch: 5 Average loss: 110.8894
# ====> Epoch: 6 Average loss: 109.8315
# ====> Epoch: 7 Average loss: 109.0097
# ====> Epoch: 8 Average loss: 108.3887
# ====> Epoch: 9 Average loss: 107.9239
# Model :
# Linear(in_features=784, out_features=400, bias=True)
# Sparsity in Layer 0: 0.00%
# Linear(in_features=400, out_features=200, bias=True)
# Sparsity in Layer 1: 0.00%
# Linear(in_features=200, out_features=100, bias=True)
# Sparsity in Layer 2: 0.00%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 3: 0.00%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 4: 0.00%
# Linear(in_features=32, out_features=100, bias=True)
# Sparsity in Layer 5: 0.00%
# Linear(in_features=100, out_features=200, bias=True)
# Sparsity in Layer 6: 0.00%
# Linear(in_features=200, out_features=400, bias=True)
# Sparsity in Layer 7: 0.00%
# Linear(in_features=400, out_features=784, bias=True)
# Sparsity in Layer 8: 0.00%
# Global Sparsity : 0.00%
# 11.0 % of weights pruned
# ====> Epoch: 0 Average loss: 133.1559
# ====> Epoch: 1 Average loss: 120.1782
# ====> Epoch: 2 Average loss: 115.1905
# ====> Epoch: 3 Average loss: 112.2508
# ====> Epoch: 4 Average loss: 110.6487
# ====> Epoch: 5 Average loss: 109.5188
# ====> Epoch: 6 Average loss: 108.8606
# ====> Epoch: 7 Average loss: 108.3138
# ====> Epoch: 8 Average loss: 107.8239
# ====> Epoch: 9 Average loss: 107.4734
# Model :
# Linear(in_features=784, out_features=400, bias=True)
# Sparsity in Layer 0: 13.11%
# Linear(in_features=400, out_features=200, bias=True)
# Sparsity in Layer 1: 12.85%
# Linear(in_features=200, out_features=100, bias=True)
# Sparsity in Layer 2: 9.89%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 3: 36.81%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 4: 55.62%
# Linear(in_features=32, out_features=100, bias=True)
# Sparsity in Layer 5: 4.47%
# Linear(in_features=100, out_features=200, bias=True)
# Sparsity in Layer 6: 6.25%
# Linear(in_features=200, out_features=400, bias=True)
# Sparsity in Layer 7: 7.40%
# Linear(in_features=400, out_features=784, bias=True)
# Sparsity in Layer 8: 9.05%
# Global Sparsity : 11.00%
# 22.0 % of weights pruned
# ====> Epoch: 0 Average loss: 132.7909
# ====> Epoch: 1 Average loss: 119.1583
# ====> Epoch: 2 Average loss: 114.0003
# ====> Epoch: 3 Average loss: 111.2553
# ====> Epoch: 4 Average loss: 109.5379
# ====> Epoch: 5 Average loss: 108.6353
# ====> Epoch: 6 Average loss: 107.9545
# ====> Epoch: 7 Average loss: 107.5090
# ====> Epoch: 8 Average loss: 107.0671
# ====> Epoch: 9 Average loss: 106.7750
# Model :
# Linear(in_features=784, out_features=400, bias=True)
# Sparsity in Layer 0: 26.02%
# Linear(in_features=400, out_features=200, bias=True)
# Sparsity in Layer 1: 25.52%
# Linear(in_features=200, out_features=100, bias=True)
# Sparsity in Layer 2: 20.45%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 3: 61.03%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 4: 69.09%
# Linear(in_features=32, out_features=100, bias=True)
# Sparsity in Layer 5: 8.59%
# Linear(in_features=100, out_features=200, bias=True)
# Sparsity in Layer 6: 13.06%
# Linear(in_features=200, out_features=400, bias=True)
# Sparsity in Layer 7: 15.98%
# Linear(in_features=400, out_features=784, bias=True)
# Sparsity in Layer 8: 18.54%
# Global Sparsity : 22.00%
# 33.0 % of weights pruned
# ====> Epoch: 0 Average loss: 132.2183
# ====> Epoch: 1 Average loss: 117.7130
# ====> Epoch: 2 Average loss: 112.7322
# ====> Epoch: 3 Average loss: 110.2057
# ====> Epoch: 4 Average loss: 108.6221
# ====> Epoch: 5 Average loss: 107.7222
# ====> Epoch: 6 Average loss: 107.1704
# ====> Epoch: 7 Average loss: 106.7794
# ====> Epoch: 8 Average loss: 106.4382
# ====> Epoch: 9 Average loss: 106.2485
# Model :
# Linear(in_features=784, out_features=400, bias=True)
# Sparsity in Layer 0: 39.58%
# Linear(in_features=400, out_features=200, bias=True)
# Sparsity in Layer 1: 37.58%
# Linear(in_features=200, out_features=100, bias=True)
# Sparsity in Layer 2: 30.30%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 3: 70.97%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 4: 76.69%
# Linear(in_features=32, out_features=100, bias=True)
# Sparsity in Layer 5: 11.38%
# Linear(in_features=100, out_features=200, bias=True)
# Sparsity in Layer 6: 19.36%
# Linear(in_features=200, out_features=400, bias=True)
# Sparsity in Layer 7: 24.11%
# Linear(in_features=400, out_features=784, bias=True)
# Sparsity in Layer 8: 27.95%
# Global Sparsity : 33.00%
# 44.0 % of weights pruned
# ====> Epoch: 0 Average loss: 132.0475
# ====> Epoch: 1 Average loss: 116.5149
# ====> Epoch: 2 Average loss: 111.3829
# ====> Epoch: 3 Average loss: 108.6895
# ====> Epoch: 4 Average loss: 107.5045
# ====> Epoch: 5 Average loss: 106.8039
# ====> Epoch: 6 Average loss: 106.4573
# ====> Epoch: 7 Average loss: 106.1008
# ====> Epoch: 8 Average loss: 105.8727
# ====> Epoch: 9 Average loss: 105.7098
# Model :
# Linear(in_features=784, out_features=400, bias=True)
# Sparsity in Layer 0: 53.51%
# Linear(in_features=400, out_features=200, bias=True)
# Sparsity in Layer 1: 48.40%
# Linear(in_features=200, out_features=100, bias=True)
# Sparsity in Layer 2: 39.20%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 3: 74.56%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 4: 81.72%
# Linear(in_features=32, out_features=100, bias=True)
# Sparsity in Layer 5: 13.97%
# Linear(in_features=100, out_features=200, bias=True)
# Sparsity in Layer 6: 24.53%
# Linear(in_features=200, out_features=400, bias=True)
# Sparsity in Layer 7: 31.60%
# Linear(in_features=400, out_features=784, bias=True)
# Sparsity in Layer 8: 37.69%
# Global Sparsity : 44.00%
# 55.0 % of weights pruned
# ====> Epoch: 0 Average loss: 132.5793
# ====> Epoch: 1 Average loss: 115.8381
# ====> Epoch: 2 Average loss: 110.3560
# ====> Epoch: 3 Average loss: 107.7847
# ====> Epoch: 4 Average loss: 106.7385
# ====> Epoch: 5 Average loss: 106.1573
# ====> Epoch: 6 Average loss: 105.8269
# ====> Epoch: 7 Average loss: 105.5349
# ====> Epoch: 8 Average loss: 105.4070
# ====> Epoch: 9 Average loss: 105.2558
# Model :
# Linear(in_features=784, out_features=400, bias=True)
# Sparsity in Layer 0: 67.24%
# Linear(in_features=400, out_features=200, bias=True)
# Sparsity in Layer 1: 58.41%
# Linear(in_features=200, out_features=100, bias=True)
# Sparsity in Layer 2: 47.48%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 3: 77.66%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 4: 85.41%
# Linear(in_features=32, out_features=100, bias=True)
# Sparsity in Layer 5: 18.09%
# Linear(in_features=100, out_features=200, bias=True)
# Sparsity in Layer 6: 29.55%
# Linear(in_features=200, out_features=400, bias=True)
# Sparsity in Layer 7: 39.10%
# Linear(in_features=400, out_features=784, bias=True)
# Sparsity in Layer 8: 47.89%
# Global Sparsity : 55.00%
# 66.0 % of weights pruned
# ====> Epoch: 0 Average loss: 135.0905
# ====> Epoch: 1 Average loss: 116.1397
# ====> Epoch: 2 Average loss: 110.4761
# ====> Epoch: 3 Average loss: 107.5129
# ====> Epoch: 4 Average loss: 106.4342
# ====> Epoch: 5 Average loss: 105.9290
# ====> Epoch: 6 Average loss: 105.5759
# ====> Epoch: 7 Average loss: 105.3437
# ====> Epoch: 8 Average loss: 105.1978
# ====> Epoch: 9 Average loss: 105.0804
# Model :
# Linear(in_features=784, out_features=400, bias=True)
# Sparsity in Layer 0: 79.43%
# Linear(in_features=400, out_features=200, bias=True)
# Sparsity in Layer 1: 68.91%
# Linear(in_features=200, out_features=100, bias=True)
# Sparsity in Layer 2: 56.78%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 3: 80.38%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 4: 89.12%
# Linear(in_features=32, out_features=100, bias=True)
# Sparsity in Layer 5: 24.69%
# Linear(in_features=100, out_features=200, bias=True)
# Sparsity in Layer 6: 35.51%
# Linear(in_features=200, out_features=400, bias=True)
# Sparsity in Layer 7: 48.08%
# Linear(in_features=400, out_features=784, bias=True)
# Sparsity in Layer 8: 58.97%
# Global Sparsity : 66.00%
# 77.0 % of weights pruned
# ====> Epoch: 0 Average loss: 142.0967
# ====> Epoch: 1 Average loss: 119.9520
# ====> Epoch: 2 Average loss: 112.6200
# ====> Epoch: 3 Average loss: 109.0203
# ====> Epoch: 4 Average loss: 107.3848
# ====> Epoch: 5 Average loss: 106.7488
# ====> Epoch: 6 Average loss: 106.3208
# ====> Epoch: 7 Average loss: 106.0891
# ====> Epoch: 8 Average loss: 105.9080
# ====> Epoch: 9 Average loss: 105.7635
# Model :
# Linear(in_features=784, out_features=400, bias=True)
# Sparsity in Layer 0: 88.62%
# Linear(in_features=400, out_features=200, bias=True)
# Sparsity in Layer 1: 80.05%
# Linear(in_features=200, out_features=100, bias=True)
# Sparsity in Layer 2: 68.53%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 3: 83.38%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 4: 92.09%
# Linear(in_features=32, out_features=100, bias=True)
# Sparsity in Layer 5: 33.56%
# Linear(in_features=100, out_features=200, bias=True)
# Sparsity in Layer 6: 43.31%
# Linear(in_features=200, out_features=400, bias=True)
# Sparsity in Layer 7: 59.61%
# Linear(in_features=400, out_features=784, bias=True)
# Sparsity in Layer 8: 71.95%
# Global Sparsity : 77.00%
# 88.0 % of weights pruned
# ====> Epoch: 0 Average loss: 166.7256
# ====> Epoch: 1 Average loss: 135.8481
# ====> Epoch: 2 Average loss: 124.9864
# ====> Epoch: 3 Average loss: 119.2320
# ====> Epoch: 4 Average loss: 115.6194
# ====> Epoch: 5 Average loss: 113.5277
# ====> Epoch: 6 Average loss: 111.7308
# ====> Epoch: 7 Average loss: 110.9050
# ====> Epoch: 8 Average loss: 110.4006
# ====> Epoch: 9 Average loss: 110.0611
# Model :
# Linear(in_features=784, out_features=400, bias=True)
# Sparsity in Layer 0: 95.21%
# Linear(in_features=400, out_features=200, bias=True)
# Sparsity in Layer 1: 90.17%
# Linear(in_features=200, out_features=100, bias=True)
# Sparsity in Layer 2: 82.24%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 3: 87.88%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 4: 94.84%
# Linear(in_features=32, out_features=100, bias=True)
# Sparsity in Layer 5: 49.16%
# Linear(in_features=100, out_features=200, bias=True)
# Sparsity in Layer 6: 54.72%
# Linear(in_features=200, out_features=400, bias=True)
# Sparsity in Layer 7: 75.73%
# Linear(in_features=400, out_features=784, bias=True)
# Sparsity in Layer 8: 86.19%
# Global Sparsity : 88.00%
# 99.0 % of weights pruned
# ====> Epoch: 0 Average loss: 279.5077
# ====> Epoch: 1 Average loss: 229.8089
# ====> Epoch: 2 Average loss: 220.6549
# ====> Epoch: 3 Average loss: 215.6099
# ====> Epoch: 4 Average loss: 212.4866
# ====> Epoch: 5 Average loss: 210.4515
# ====> Epoch: 6 Average loss: 209.0927
# ====> Epoch: 7 Average loss: 208.1668
# ====> Epoch: 8 Average loss: 207.5241
# ====> Epoch: 9 Average loss: 207.0834
# ====> Epoch: 10 Average loss: 201.7509
# ====> Epoch: 11 Average loss: 195.8140
# ====> Epoch: 12 Average loss: 189.9186
# ====> Epoch: 13 Average loss: 185.1740
# ====> Epoch: 14 Average loss: 180.9494
# ====> Epoch: 15 Average loss: 177.3204
# ====> Epoch: 16 Average loss: 174.2503
# ====> Epoch: 17 Average loss: 172.5501
# ====> Epoch: 18 Average loss: 171.2630
# ====> Epoch: 19 Average loss: 170.3499
# Model :
# Linear(in_features=784, out_features=400, bias=True)
# Sparsity in Layer 0: 99.75%
# Linear(in_features=400, out_features=200, bias=True)
# Sparsity in Layer 1: 99.27%
# Linear(in_features=200, out_features=100, bias=True)
# Sparsity in Layer 2: 98.17%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 3: 96.09%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 4: 98.94%
# Linear(in_features=32, out_features=100, bias=True)
# Sparsity in Layer 5: 86.59%
# Linear(in_features=100, out_features=200, bias=True)
# Sparsity in Layer 6: 87.42%
# Linear(in_features=200, out_features=400, bias=True)
# Sparsity in Layer 7: 98.11%
# Linear(in_features=400, out_features=784, bias=True)
# Sparsity in Layer 8: 99.35%
# Global Sparsity : 99.00%
# Model :
# Linear(in_features=784, out_features=400, bias=True)
# Sparsity in Layer 0: 99.75%
# Linear(in_features=400, out_features=200, bias=True)
# Sparsity in Layer 1: 99.27%
# Linear(in_features=200, out_features=100, bias=True)
# Sparsity in Layer 2: 98.17%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 3: 96.09%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 4: 98.94%
# Linear(in_features=32, out_features=100, bias=True)
# Sparsity in Layer 5: 86.59%
# Linear(in_features=100, out_features=200, bias=True)
# Sparsity in Layer 6: 87.42%
# Linear(in_features=200, out_features=400, bias=True)
# Sparsity in Layer 7: 98.11%
# Linear(in_features=400, out_features=784, bias=True)
# Sparsity in Layer 8: 99.35%
# Global Sparsity : 99.00%

# %%
for epoch in range(31,50):

        model.train()
        train_loss = 0
        for batch_idx, (data, _) in enumerate(mnist_trainset):
            data = data.to(device)
            optimizer.zero_grad()
            recon_batch, mu, logvar = model(data)
            beta = 1
            loss = loss_function(recon_batch, data, mu, logvar, beta)
            loss.backward()
            train_loss += loss.item()
            optimizer.step()
            step += 1
            
            if  first_training and batch_idx == 500 :
                rewind_state_dict = copy.deepcopy(model.state_dict())
                first_training = False
                print('rewind state saved')
            
            #if batch_idx % log_interval == 0:
            #    print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            #        epoch, batch_idx * len(data), len(mnist_trainset.dataset),
            #        100. * batch_idx / len(mnist_trainset),
            #        loss.item() / len(data)))
            #    plt_loss.append(loss.item() / len(data))  # For ploting loss
        print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / len(mnist_trainset.dataset)))
_, _, _ = model(data)
prstat.stats_pruning(model)
# Out:
# ====> Epoch: 31 Average loss: 167.0520
# ====> Epoch: 32 Average loss: 166.7728
# ====> Epoch: 33 Average loss: 166.4616
# ====> Epoch: 34 Average loss: 166.0388
# ====> Epoch: 35 Average loss: 165.6754
# ====> Epoch: 36 Average loss: 165.3309
# ====> Epoch: 37 Average loss: 164.9875
# ====> Epoch: 38 Average loss: 164.7251
# ====> Epoch: 39 Average loss: 164.5643
# ====> Epoch: 40 Average loss: 164.4707
# ====> Epoch: 41 Average loss: 164.3246
# ====> Epoch: 42 Average loss: 164.2883
# ====> Epoch: 43 Average loss: 164.2213
# ====> Epoch: 44 Average loss: 164.1321
# ====> Epoch: 45 Average loss: 164.0421
# ====> Epoch: 46 Average loss: 164.0200
# ====> Epoch: 47 Average loss: 163.9758
# ====> Epoch: 48 Average loss: 163.9093
# ====> Epoch: 49 Average loss: 163.8431
# Model :
# Linear(in_features=784, out_features=400, bias=True)
# Sparsity in Layer 0: 99.75%
# Linear(in_features=400, out_features=200, bias=True)
# Sparsity in Layer 1: 99.27%
# Linear(in_features=200, out_features=100, bias=True)
# Sparsity in Layer 2: 98.17%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 3: 96.09%
# Linear(in_features=100, out_features=32, bias=True)
# Sparsity in Layer 4: 98.94%
# Linear(in_features=32, out_features=100, bias=True)
# Sparsity in Layer 5: 86.59%
# Linear(in_features=100, out_features=200, bias=True)
# Sparsity in Layer 6: 87.42%
# Linear(in_features=200, out_features=400, bias=True)
# Sparsity in Layer 7: 98.11%
# Linear(in_features=400, out_features=784, bias=True)
# Sparsity in Layer 8: 99.35%
# Global Sparsity : 99.00%
